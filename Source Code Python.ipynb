# %%
## Phân tích sự tương quan

# %%
# cài đặt môi trường kết nối tới dữ liệu
#These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# ...
#   Using cached ibm_db-3.1.0-py3-none-any.whl
# ...
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# ...
#   Using cached SQLAlchemy-2.0.15-cp39-cp39-win_amd64.whl (2.0 MB)
# ...
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# ...
#   Using cached greenlet-2.0.2-cp39-cp39-win_amd64.whl (192 kB)
# ...
#   Attempting uninstall: ibm_db
#     Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
#       Successfully uninstalled ibm-db-3.1.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.1
#     Uninstalling greenlet-1.1.1:
#       Successfully uninstalled greenlet-1.1.1
# ...
# Found existing installation: SQLAlchemy 2.0.15
# Uninstalling SQLAlchemy-2.0.15:
#   Successfully uninstalled SQLAlchemy-2.0.15
# ...

# %%
# %load_ext sql

# %%
#kết nối tới ibm database và kết nối tới dữ liệu khảo sát
# %sql ibm_db_sa://pff02138:SGbcSf3UXCxnK6Q2@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/BLUDB?security=SSL
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 283, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 552, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 366, in load
#     return impl.load()
#   File "C:\Users\ACER\anaconda3\lib\importlib\metadata.py", line 86, in load
#     module = import_module(match.group('module'))
# ...

# %%
import pandas as pd
import sqlite3

# %%
#tạo các biến chứa giá trị các tham số liên quan với nhau
df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='nang_luc_lanh_dao_va_thai_do_cua_cap_tren';
nang_luc_lanh_dao_va_thai_do_cua_cap_tren=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='muc_luong_phu_hop';
muc_luong_phu_hop=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='dam_bao_phuc_loi';
dam_bao_phuc_loi=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='moi_truong_lam_viec_nghiem_tuc';
moi_truong_lam_viec_nghiem_tuc=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='moi_truong_lam_viec_thoai_mai_nang_dong';
moi_truong_lam_viec_thoai_mai_nang_dong=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Thai_do_va_nang_luc_cua_dong_nghiep';
Thai_do_va_nang_luc_cua_dong_nghiep=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty';
Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Co_quy_trinh_dao_tao_nhan_vien_moi';
Co_quy_trinh_dao_tao_nhan_vien_moi=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Kinh_nghiem_nhan_duoc';
Kinh_nghiem_nhan_duoc=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Nghi_phep_nghi_le_trong_nam_nhieu';
Nghi_phep_nghi_le_trong_nam_nhieu=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Che_do_tien_thuong_Tet_dip_le_Overtime';
Che_do_tien_thuong_Tet_dip_le_Overtime=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Lo_trinh_phat_trien_cua_cong_ty';
Lo_trinh_phat_trien_cua_cong_ty=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Thuong_xuyen_tang_ca';
Thuong_xuyen_tang_ca=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Thuong_xuyen_thay_doi_dia_diem_lam_viec';
Thuong_xuyen_thay_doi_dia_diem_lam_viec=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='May_moc_thiet_bi_hien_dai';
May_moc_thiet_bi_hien_dai=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai';
Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='An_ninh_trat_tu_quanh_khu_vuc';
An_ninh_trat_tu_quanh_khu_vuc=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Thoi_gian_lam_viec';
Thoi_gian_lam_viec=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Linh_vuc_la_the_manh_cua_ban_than';
Linh_vuc_la_the_manh_cua_ban_than=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Linh_vuc_la_so_thich_cua_ban_than';
Linh_vuc_la_so_thich_cua_ban_than=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Linh_vuc_co_nhieu_doi_thu_canh_tranh';
Linh_vuc_co_nhieu_doi_thu_canh_tranh=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh';
Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh=pd.DataFrame(df)

df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh';
Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh=pd.DataFrame(df)
df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe';
Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe=pd.DataFrame(df)
df=%sql select VALUE from DATA_XLDL WHERE agrument_observation ='Linh_vuc_pho_bien';
Linh_vuc_pho_bien=pd.DataFrame(df)
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Traceback (most recent call last):
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "C:\Users\ACER\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# ...

# %%
Linh_vuc_pho_bien
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import matplotlib.pyplot as plt
import numpy as np

# Chuyển đổi cột của DataFrame thành mảng numpy
nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
muc_luong_phu_hop_arr = muc_luong_phu_hop[0].astype(float).values




plt.scatter(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr, c=muc_do_phan_bo_norm, cmap='viridis', vmin=0, vmax=1)
plt.colorbar(label='Mức độ phân bổ tập trung')
plt.xlabel('Năng lực lãnh đạo và thái độ của cấp trên')
plt.ylabel('Mức lương phù hợp')
plt.title('Biểu đồ liên hệ giữa năng lực lãnh đạo và mức lương')
# Tính hệ số Pearson
pearson_coef = np.corrcoef(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr)[0, 1]

# Vẽ đường hệ số Pearson
plt.plot(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, pearson_coef * nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, color='red', linestyle='--', label='Hệ số Pearson')

plt.legend()  # Hiển thị chú thích

# Đổi độ rộng quy mô và độ chia của cột y
plt.ylim(1, 5.5, 1)
plt.yticks(np.arange(1, 6, 1))
plt.xlim(1, 5.5, 1)
plt.xticks(np.arange(1, 6, 1))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr

nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
muc_luong_phu_hop_arr = muc_luong_phu_hop[0].astype(float).values

# Thêm jittering để tránh các điểm trùng nhau
jitter = np.random.uniform(-0.05, 0.05, size=nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.shape)
nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr += jitter

# Tính số lượng chấm tròn và bán kính đường tròn
num_dots = len(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr)
circle_radius = num_dots / 10

# Tăng độ to của chấm tròn
circle_linewidth = 2

# Phân tán đều các điểm trùng nhau
alpha = 0.5
nang_luc_va_thai_do_cua_cap_tren_name='nang luc va thai do cua cap tren'
muc_luong_phu_hop_name='muc luong phu hop'
title_name='bieu do lien he giua ' + nang_luc_va_thai_do_cua_cap_tren_name +' voi ' + muc_luong_phu_hop_name
plt.scatter(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr, cmap='viridis', s=circle_radius, linewidths=circle_linewidth, alpha=alpha)
plt.xlabel(nang_luc_va_thai_do_cua_cap_tren_name)
plt.ylabel(muc_luong_phu_hop_name)
plt.title(title_name)

# Sử dụng mô hình hồi quy tuyến tính
model = LinearRegression()
model.fit(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.reshape(-1, 1), muc_luong_phu_hop_arr.reshape(-1, 1))
predicted_values = model.predict(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.reshape(-1, 1))

# Vẽ đường thẳng tuyến tính phù hợp
plt.plot(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, predicted_values, color='red', linestyle='--', label='Đường thẳng tuyến tính phù hợp')

# Tính hệ số Pearson
pearson_coef, _ = pearsonr(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr)

plt.legend()  # Hiển thị chú thích

# Hiển thị hệ số Pearson trên đồ thị
plt.text(1, 5.5, 'Hệ số Pearson: {:.2f}'.format(pearson_coef), fontsize=6)

plt.show()

# %%
nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
muc_luong_phu_hop_new = muc_luong_phu_hop[0].astype(float).values

# Tạo DataFrame từ hai mảng ban đầu
df = pd.DataFrame({
    'năng lực làm việc và\n thái độ của cấp trên': nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new,
    'mức lương phù hợp': muc_luong_phu_hop_new
})

# Tạo các nhân tố mới và thêm vào DataFrame
moi_truong_lam_viec_nghiem_tuc_new = moi_truong_lam_viec_nghiem_tuc[0].astype(float).values
moi_truong_lam_viec_thoai_mai_nang_dong_new = moi_truong_lam_viec_thoai_mai_nang_dong[0].astype(float).values
Thai_do_va_nang_luc_cua_dong_nghiep_new = Thai_do_va_nang_luc_cua_dong_nghiep[0].astype(float).values
Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty[0].astype(float).values
Co_quy_trinh_dao_tao_nhan_vien_moi_new = Co_quy_trinh_dao_tao_nhan_vien_moi[0].astype(float).values
Kinh_nghiem_nhan_duoc_new = Kinh_nghiem_nhan_duoc[0].astype(float).values
Nghi_phep_nghi_le_trong_nam_nhieu_new = Nghi_phep_nghi_le_trong_nam_nhieu[0].astype(float).values
Che_do_tien_thuong_Tet_dip_le_Overtime_new = Che_do_tien_thuong_Tet_dip_le_Overtime[0].astype(float).values
Lo_trinh_phat_trien_cua_cong_ty_new = Lo_trinh_phat_trien_cua_cong_ty[0].astype(float).values
Thuong_xuyen_tang_ca_new = Thuong_xuyen_tang_ca[0].astype(float).values
Thuong_xuyen_thay_doi_dia_diem_lam_viec_new = Thuong_xuyen_thay_doi_dia_diem_lam_viec[0].astype(float).values
May_moc_thiet_bi_hien_dai_new = May_moc_thiet_bi_hien_dai[0].astype(float).values
Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai[0].astype(float).values
An_ninh_trat_tu_quanh_khu_vuc_new = An_ninh_trat_tu_quanh_khu_vuc[0].astype(float).values
Thoi_gian_lam_viec_new = Thoi_gian_lam_viec[0].astype(float).values
Linh_vuc_la_the_manh_cua_ban_than_new = Linh_vuc_la_the_manh_cua_ban_than[0].astype(float).values
Linh_vuc_la_so_thich_cua_ban_than_new = Linh_vuc_la_so_thich_cua_ban_than[0].astype(float).values
Linh_vuc_co_nhieu_doi_thu_canh_tranh_new = Linh_vuc_co_nhieu_doi_thu_canh_tranh[0].astype(float).values
Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new = Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh[0].astype(float).values
Linh_vuc_pho_bien_new = Linh_vuc_pho_bien[0].astype(float).values
Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe[0].astype(float).values

# Thêm các nhân tố mới vào DataFrame
df['moi_truong_lam_viec_nghiem_tuc'] = moi_truong_lam_viec_nghiem_tuc_new
df['moi_truong_lam_viec_thoai_mai_nang_dong'] = moi_truong_lam_viec_thoai_mai_nang_dong_new
df['Thai_do_va_nang_luc_cua_dong_nghiep'] = Thai_do_va_nang_luc_cua_dong_nghiep_new
df['Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty'] = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new
df['Co_quy_trinh_dao_tao_nhan_vien_moi'] = Co_quy_trinh_dao_tao_nhan_vien_moi_new
df['Kinh_nghiem_nhan_duoc'] = Kinh_nghiem_nhan_duoc_new
df['Nghi_phep_nghi_le_trong_nam_nhieu'] = Nghi_phep_nghi_le_trong_nam_nhieu_new
df['Che_do_tien_thuong_Tet_dip_le_Overtime'] = Che_do_tien_thuong_Tet_dip_le_Overtime_new
df['Lo_trinh_phat_trien_cua_cong_ty'] = Lo_trinh_phat_trien_cua_cong_ty_new
df['Thuong_xuyen_tang_ca'] = Thuong_xuyen_tang_ca_new
df['Thuong_xuyen_thay_doi_dia_diem_lam_viec'] = Thuong_xuyen_thay_doi_dia_diem_lam_viec_new
df['May_moc_thiet_bi_hien_dai'] = May_moc_thiet_bi_hien_dai_new
df['Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai'] = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new
df['An_ninh_trat_tu_quanh_khu_vuc'] = An_ninh_trat_tu_quanh_khu_vuc_new
df['Thoi_gian_lam_viec'] = Thoi_gian_lam_viec_new
df['Linh_vuc_la_the_manh_cua_ban_than'] = Linh_vuc_la_the_manh_cua_ban_than_new
df['Linh_vuc_la_so_thich_cua_ban_than'] = Linh_vuc_la_so_thich_cua_ban_than_new
df['Linh_vuc_co_nhieu_doi_thu_canh_tranh'] = Linh_vuc_co_nhieu_doi_thu_canh_tranh_new
df['Khong_gian_lam_viec_sach_se\n_thoang_dang_van_phong_nha_ve_sinh']= Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new
df['Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe']=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new
df['Linh_vuc_pho_bien'] = Linh_vuc_pho_bien_new

# Tính ma trận tương quan
corr_matrix = df.corr()

# Hiển thị ma trận tương quan
print(corr_matrix)

# Vẽ biểu đồ tương quan
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(26, 14)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát và mức độ liên hệ giữa chúng")
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Tạo DataFrame từ các mảng ban đầu
df = pd.DataFrame({
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty': Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new,
    'nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new': nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new,
    'Kinh_nghiem_nhan_duoc': Kinh_nghiem_nhan_duoc_new,
    'Che_do_tien_thuong_Tet_dip_le_Overtime':Che_do_tien_thuong_Tet_dip_le_Overtime_new,
    'Muc_luong_phu_hop':muc_luong_phu_hop_new,
    'Lo_trinh_phat_trien_cua_cong_ty':Lo_trinh_phat_trien_cua_cong_ty_new,
    'Kinh_nghiem_nhan_duoc':Kinh_nghiem_nhan_duoc_new,
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty':Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new


})

# Tính ma trận tương quan
corr_matrix = df.corr()
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 6)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát và mức độ liên hệ giữa chúng")
cmap = sns.diverging_palette(20, 10, s=80, l=50, as_cmap=True)
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression

def vedothi(nang_luc_lanh_dao_va_thai_do_cua_cap_tren, muc_luong_phu_hop, nang_luc_va_thai_do_cua_cap_tren_name, muc_luong_phu_hop_name):
    nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
    muc_luong_phu_hop_arr = muc_luong_phu_hop[0].astype(float).values

    # Thêm jittering để tránh các điểm trùng nhau
    jitter = np.random.uniform(-0.05, 0.05, size=nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.shape)
    nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr += jitter

    # Tính số lượng chấm tròn và bán kính đường tròn
    num_dots = len(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr)
    circle_radius = num_dots / 10

    # Tăng độ to của chấm tròn
    circle_linewidth = 2

    # Phân tán đều các điểm trùng nhau
    alpha = 0.5
    title_name = 'bieu do lien he giua ' + nang_luc_va_thai_do_cua_cap_tren_name + ' voi ' + muc_luong_phu_hop_name
    plt.scatter(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr, cmap='viridis', s=circle_radius, linewidths=circle_linewidth, alpha=alpha)
    plt.xlabel(nang_luc_va_thai_do_cua_cap_tren_name)
    plt.ylabel(muc_luong_phu_hop_name)
    plt.title(title_name)

    # Sử dụng mô hình hồi quy tuyến tính
    model = LinearRegression()
    model.fit(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.reshape(-1, 1), muc_luong_phu_hop_arr.reshape(-1, 1))
    predicted_values = model.predict(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr.reshape(-1, 1))

    # Vẽ đường thẳng tuyến tính phù hợp
    plt.plot(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, predicted_values, color='red', linestyle='--', label='Đường thẳng tuyến tính phù hợp')

    # Tính hệ số Pearson
    pearson_coef, _ = pearsonr(nang_luc_lanh_dao_va_thai_do_cua_cap_tren_arr, muc_luong_phu_hop_arr)

    plt.legend()  # Hiển thị chú thích

    # Hiển thị hệ số Pearson trên đồ thị
    plt.text(1, 5.5, 'Hệ số Pearson: {:.2f}'.format(pearson_coef), fontsize=6)

    plt.show()

# %%
vedothi(Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty,nang_luc_lanh_dao_va_thai_do_cua_cap_tren,'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty','nang_luc_lanh_dao_va_thai_do_cua_cap_tren')
vedothi(Kinh_nghiem_nhan_duoc,nang_luc_lanh_dao_va_thai_do_cua_cap_tren,'Kinh_nghiem_nhan_duoc','nang_luc_lanh_dao_va_thai_do_cua_cap_tren')
vedothi(Kinh_nghiem_nhan_duoc,Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty,'Kinh_nghiem_nhan_duoc','Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty')
vedothi(Lo_trinh_phat_trien_cua_cong_ty,Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty,'Lo_trinh_phat_trien_cua_cong_ty','Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty')
vedothi(muc_luong_phu_hop,Che_do_tien_thuong_Tet_dip_le_Overtime,'Muc_luong_phu_hop','Che_do_tien_thuong_Tet_dip_le_Overtime')

# %%
import pandas as pd
import seaborn as sns

# Tạo DataFrame từ các mảng ban đầu
df = pd.DataFrame({
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty': Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new,
    'nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new': nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new,
    'Kinh_nghiem_nhan_duoc': Kinh_nghiem_nhan_duoc_new,
    'Che_do_tien_thuong_Tet_dip_le_Overtime':Che_do_tien_thuong_Tet_dip_le_Overtime_new,
    'Muc_luong_phu_hop':muc_luong_phu_hop_new,
    'Lo_trinh_phat_trien_cua_cong_ty':Lo_trinh_phat_trien_cua_cong_ty_new,
    'Kinh_nghiem_nhan_duoc':Kinh_nghiem_nhan_duoc_new,
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty':Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new


})

# Tính ma trận tương quan
corr_matrix = df.corr()
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 6)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát và mức độ liên hệ giữa chúng")
cmap = sns.diverging_palette(20, 10, s=80, l=50, as_cmap=True)
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
import pandas as pd
import seaborn as sns

# Tạo DataFrame từ các mảng ban đầu
df = pd.DataFrame({
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty': Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new,
    'nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new': nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new,
    'Kinh_nghiem_nhan_duoc': Kinh_nghiem_nhan_duoc_new,
    'Che_do_tien_thuong_Tet_dip_le_Overtime':Che_do_tien_thuong_Tet_dip_le_Overtime_new,
    'Muc_luong_phu_hop':muc_luong_phu_hop_new,
    'Lo_trinh_phat_trien_cua_cong_ty':Lo_trinh_phat_trien_cua_cong_ty_new,
    'Kinh_nghiem_nhan_duoc':Kinh_nghiem_nhan_duoc_new,
    'Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty':Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new


})

# Tính ma trận tương quan
corr_matrix = df.corr()
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 6)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát và mức độ liên hệ giữa chúng")
cmap = sns.diverging_palette(20, 10, s=80, l=50, as_cmap=True)
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
def changename(variable):
    for name, value in globals().items():
        if value is variable:
            return name
    return None

x = 1
variable_name = changename(_nang_luc_va_thai_do_cua_cap_tren_)
print(variable_name)  # Kết quả: 'x'

# %%
x = 1
variable_name = changename(x)
print(variable_name)  # Kết quả: 'x'

# %%
# nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
# muc_luong_phu_hop_new = muc_luong_phu_hop[0].astype(float).values

# Tạo DataFrame từ hai mảng ban đầu
df1 = pd.DataFrame({
})

# Tạo các nhân tố mới và thêm vào DataFrame
moi_truong_lam_viec_nghiem_tuc_new = moi_truong_lam_viec_nghiem_tuc[0].astype(float).values
moi_truong_lam_viec_thoai_mai_nang_dong_new = moi_truong_lam_viec_thoai_mai_nang_dong[0].astype(float).values
Thai_do_va_nang_luc_cua_dong_nghiep_new = Thai_do_va_nang_luc_cua_dong_nghiep[0].astype(float).values
Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty[0].astype(float).values
Co_quy_trinh_dao_tao_nhan_vien_moi_new = Co_quy_trinh_dao_tao_nhan_vien_moi[0].astype(float).values
Kinh_nghiem_nhan_duoc_new = Kinh_nghiem_nhan_duoc[0].astype(float).values
Nghi_phep_nghi_le_trong_nam_nhieu_new = Nghi_phep_nghi_le_trong_nam_nhieu[0].astype(float).values
Che_do_tien_thuong_Tet_dip_le_Overtime_new = Che_do_tien_thuong_Tet_dip_le_Overtime[0].astype(float).values
Lo_trinh_phat_trien_cua_cong_ty_new = Lo_trinh_phat_trien_cua_cong_ty[0].astype(float).values
Thuong_xuyen_tang_ca_new = Thuong_xuyen_tang_ca[0].astype(float).values
Thuong_xuyen_thay_doi_dia_diem_lam_viec_new = Thuong_xuyen_thay_doi_dia_diem_lam_viec[0].astype(float).values
May_moc_thiet_bi_hien_dai_new = May_moc_thiet_bi_hien_dai[0].astype(float).values
Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai[0].astype(float).values
An_ninh_trat_tu_quanh_khu_vuc_new = An_ninh_trat_tu_quanh_khu_vuc[0].astype(float).values
Thoi_gian_lam_viec_new = Thoi_gian_lam_viec[0].astype(float).values
Linh_vuc_la_the_manh_cua_ban_than_new = Linh_vuc_la_the_manh_cua_ban_than[0].astype(float).values
Linh_vuc_la_so_thich_cua_ban_than_new = Linh_vuc_la_so_thich_cua_ban_than[0].astype(float).values
Linh_vuc_co_nhieu_doi_thu_canh_tranh_new = Linh_vuc_co_nhieu_doi_thu_canh_tranh[0].astype(float).values
Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new = Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh[0].astype(float).values
Linh_vuc_pho_bien_new = Linh_vuc_pho_bien[0].astype(float).values
Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe[0].astype(float).values

# Thêm các nhân tố mới vào DataFrame
  
# df['moi_truong_lam_viec_nghiem_tuc'] = moi_truong_lam_viec_nghiem_tuc_new
# df['moi_truong_lam_viec_thoai_mai_nang_dong'] = moi_truong_lam_viec_thoai_mai_nang_dong_new
# df['Thai_do_va_nang_luc_cua_dong_nghiep'] = Thai_do_va_nang_luc_cua_dong_nghiep_new
# df['Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty'] = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new
# df['Co_quy_trinh_dao_tao_nhan_vien_moi'] = Co_quy_trinh_dao_tao_nhan_vien_moi_new
# df['Kinh_nghiem_nhan_duoc'] = Kinh_nghiem_nhan_duoc_new
# df['Nghi_phep_nghi_le_trong_nam_nhieu'] = Nghi_phep_nghi_le_trong_nam_nhieu_new
# df['Che_do_tien_thuong_Tet_dip_le_Overtime'] = Che_do_tien_thuong_Tet_dip_le_Overtime_new
# df['Lo_trinh_phat_trien_cua_cong_ty'] = Lo_trinh_phat_trien_cua_cong_ty_new
# df['Thuong_xuyen_tang_ca'] = Thuong_xuyen_tang_ca_new
# df['Thuong_xuyen_thay_doi_dia_diem_lam_viec'] = Thuong_xuyen_thay_doi_dia_diem_lam_viec_new
df1['May_moc_thiet_bi_hien_dai'] = May_moc_thiet_bi_hien_dai_new
# df['Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai'] = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new
# df['An_ninh_trat_tu_quanh_khu_vuc'] = An_ninh_trat_tu_quanh_khu_vuc_new
# df['Thoi_gian_lam_viec'] = Thoi_gian_lam_viec_new
# df['Linh_vuc_la_the_manh_cua_ban_than'] = Linh_vuc_la_the_manh_cua_ban_than_new
# df['Linh_vuc_la_so_thich_cua_ban_than'] = Linh_vuc_la_so_thich_cua_ban_than_new
# df['Linh_vuc_co_nhieu_doi_thu_canh_tranh'] = Linh_vuc_co_nhieu_doi_thu_canh_tranh_new
df1['Khong_gian_lam_viec_sach_se\n_thoang_dang_van_phong_nha_ve_sinh']= Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new
df1['Nhieu_tien_ich_co_san\n_tu_lanh_do_an_vat_cafe']=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new
# df['Linh_vuc_pho_bien'] = Linh_vuc_pho_bien_new

# Tính ma trận tương quan
corr_matrix = df1.corr()

# Hiển thị ma trận tương quan
print(corr_matrix)

# Vẽ biểu đồ tương quan
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 7)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát trong nhóm nhân tố cơ sở vật chất")
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new = nang_luc_lanh_dao_va_thai_do_cua_cap_tren[0].astype(float).values
muc_luong_phu_hop_new = muc_luong_phu_hop[0].astype(float).values

# Tạo DataFrame từ hai mảng ban đầu
df6 = pd.DataFrame({
})

# Tạo các nhân tố mới và thêm vào DataFrame
moi_truong_lam_viec_nghiem_tuc_new = moi_truong_lam_viec_nghiem_tuc[0].astype(float).values
moi_truong_lam_viec_thoai_mai_nang_dong_new = moi_truong_lam_viec_thoai_mai_nang_dong[0].astype(float).values
Thai_do_va_nang_luc_cua_dong_nghiep_new = Thai_do_va_nang_luc_cua_dong_nghiep[0].astype(float).values
Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty[0].astype(float).values
Co_quy_trinh_dao_tao_nhan_vien_moi_new = Co_quy_trinh_dao_tao_nhan_vien_moi[0].astype(float).values
Kinh_nghiem_nhan_duoc_new = Kinh_nghiem_nhan_duoc[0].astype(float).values
Nghi_phep_nghi_le_trong_nam_nhieu_new = Nghi_phep_nghi_le_trong_nam_nhieu[0].astype(float).values
Che_do_tien_thuong_Tet_dip_le_Overtime_new = Che_do_tien_thuong_Tet_dip_le_Overtime[0].astype(float).values
Lo_trinh_phat_trien_cua_cong_ty_new = Lo_trinh_phat_trien_cua_cong_ty[0].astype(float).values
Thuong_xuyen_tang_ca_new = Thuong_xuyen_tang_ca[0].astype(float).values
Thuong_xuyen_thay_doi_dia_diem_lam_viec_new = Thuong_xuyen_thay_doi_dia_diem_lam_viec[0].astype(float).values
May_moc_thiet_bi_hien_dai_new = May_moc_thiet_bi_hien_dai[0].astype(float).values
Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai[0].astype(float).values
An_ninh_trat_tu_quanh_khu_vuc_new = An_ninh_trat_tu_quanh_khu_vuc[0].astype(float).values
Thoi_gian_lam_viec_new = Thoi_gian_lam_viec[0].astype(float).values
Linh_vuc_la_the_manh_cua_ban_than_new = Linh_vuc_la_the_manh_cua_ban_than[0].astype(float).values
Linh_vuc_la_so_thich_cua_ban_than_new = Linh_vuc_la_so_thich_cua_ban_than[0].astype(float).values
Linh_vuc_co_nhieu_doi_thu_canh_tranh_new = Linh_vuc_co_nhieu_doi_thu_canh_tranh[0].astype(float).values
Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new = Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh[0].astype(float).values
Linh_vuc_pho_bien_new = Linh_vuc_pho_bien[0].astype(float).values
Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe[0].astype(float).values

# # Thêm các nhân tố mới vào DataFrame
# df5['nang_luc_lanh_dao\n_va_thai_do_cua_cap_tren']=nang_luc_lanh_dao_va_thai_do_cua_cap_tren_new
# # df4['muc_luong_phu_hop']= muc_luong_phu_hop_new
# df5['moi_truong_lam\n_viec_nghiem_tuc'] = moi_truong_lam_viec_nghiem_tuc_new
# df5['moi_truong_lam\n_viec_thoai_mai_nang_dong'] = moi_truong_lam_viec_thoai_mai_nang_dong_new
# df5['Thai_do_va_nang\n_luc_cua_dong_nghiep'] = Thai_do_va_nang_luc_cua_dong_nghiep_new
# # df2['Lo_trinh_phat_trien\n_cua_ban_than_trong_cong_ty'] = Lo_trinh_phat_trien_cua_ban_than_trong_cong_ty_new
# # df2['Co_quy_trinh_dao_tao\n_nhan_vien_moi'] = Co_quy_trinh_dao_tao_nhan_vien_moi_new
# # df2['Kinh_nghiem_nhan_duoc'] = Kinh_nghiem_nhan_duoc_new
# df4['Nghi_phep_nghi_le\n_trong_nam_nhieu'] = Nghi_phep_nghi_le_trong_nam_nhieu_new
# df4['Che_do_tien_thuong\n_Tet_dip_le_Overtime'] = Che_do_tien_thuong_Tet_dip_le_Overtime_new
# # df2['Lo_trinh_phat_trien\n_cua_cong_ty'] = Lo_trinh_phat_trien_cua_cong_ty_new
df6['Thuong_xuyen_tang_ca'] = Thuong_xuyen_tang_ca_new
df6['Thuong_xuyen_thay\n_doi_dia_diem_lam_viec'] = Thuong_xuyen_thay_doi_dia_diem_lam_viec_new
# # df['May_moc_thiet_bi_hien_dai'] = May_moc_thiet_bi_hien_dai_new
df6['Cong_ty_nam_o_noi\n_thuan_tien_cho_viec_di_lai'] = Cong_ty_nam_o_noi_thuan_tien_cho_viec_di_lai_new
df6['An_ninh_trat_tu\n_quanh_khu_vuc'] = An_ninh_trat_tu_quanh_khu_vuc_new
df6['Thoi_gian_lam_viec'] = Thoi_gian_lam_viec_new
# # df3['Linh_vuc_la_the_manh\n_cua_ban_than'] = Linh_vuc_la_the_manh_cua_ban_than_new
# # df3['Linh_vuc_la_so_thich\n_cua_ban_than'] = Linh_vuc_la_so_thich_cua_ban_than_new
# # df3['Linh_vuc_co_nhieu\n_doi_thu_canh_tranh'] = Linh_vuc_co_nhieu_doi_thu_canh_tranh_new
# # # df['Khong_gian_lam_viec_sach_se\n_thoang_dang_van_phong_nha_ve_sinh']= Khong_gian_lam_viec_sach_se_thoang_dang_van_phong_nha_ve_sinh_new
# df4['Nhieu_tien_ich_co_san\n_tu_lanh_do_an_vat_cafe']=Nhieu_tien_ich_co_san_tu_lanh_do_an_vat_cafe_new
# # df3['Linh_vuc_pho_bien'] = Linh_vuc_pho_bien_new

# Tính ma trận tương quan
corr_matrix = df6.corr()

# Hiển thị ma trận tương quan
print(corr_matrix)

# Vẽ biểu đồ tương quan
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 7)) 
plt.title("Biểu đồ thể hiện sự tương quan giữa các biến quan sát trong nhóm nhân tố Về vị trí và địa điểm làm việc  ")
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
moi_truong_lam_viec_nghiem_tuc_new
